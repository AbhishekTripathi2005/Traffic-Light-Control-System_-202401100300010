# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/traffic_data.csv')

# %%
print(df.head())
# Out:
#          Date  PageViews  UniqueVisitors  BounceRate
# 0  2024-01-01        828            1261   54.420009
# 1  2024-01-02       7065            4225   31.583887
# 2  2024-01-03       5861            3286   68.284703
# 3  2024-01-04       7163             651   60.203175
# 4  2024-01-05       9432             548   37.963247

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
sns.set(style="whitegrid")

# %%
fig, ax = plt.subplots(3, 1, figsize=(10, 10))

# Plot PageViews
ax[0].plot(df['Date'], df['PageViews'], marker='o', color='b', label='PageViews')
ax[0].set_title('PageViews Over Time')
ax[0].set_xlabel('Date')
ax[0].set_ylabel('PageViews')
ax[0].legend()

# Plot UniqueVisitors
ax[1].plot(df['Date'], df['UniqueVisitors'], marker='o', color='g', label='Unique Visitors')
ax[1].set_title('Unique Visitors Over Time')
ax[1].set_xlabel('Date')
ax[1].set_ylabel('Unique Visitors')
ax[1].legend()

# Plot BounceRate
ax[2].plot(df['Date'], df['BounceRate'], marker='o', color='r', label='BounceRate')
ax[2].set_title('Bounce Rate Over Time')
ax[2].set_xlabel('Date')
ax[2].set_ylabel('Bounce Rate (%)')
ax[2].legend()

for axes in ax:
    for label in axes.get_xticklabels():
        label.set_rotation(45)

# Show the plot
plt.tight_layout()
plt.show()
